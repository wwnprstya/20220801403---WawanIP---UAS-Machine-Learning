# %% [markdown]
# SOAL ESSAY
#
# 1. Jelaskan bagaimana memanfaatkan Machine Learning untuk Call API!
#
#     - Memilih dan Melatih Model Machine Learning
#
#       **Pemilihan Model**:
#         1. Tentukan masalah yang ingin Anda selesaikan.
#         2. Pilih algoritma machine learning yang sesuai berdasarkan kebutuhan dan karakteristik data.
#
#       **Pengumpulan Data**:
#         1. Kumpulkan data yang relevan untuk pelatihan model.
#         2. Lakukan pembersihan data (menghapus duplikasi, menangani nilai hilang, dll.).
#         3. Bagi data menjadi set pelatihan dan set pengujian.
#
#       **Pelatihan Model**:
#         1. Gunakan set pelatihan untuk melatih model.
#         2. Lakukan tuning hyperparameter untuk meningkatkan kinerja model.
#         3. Evaluasi model menggunakan set pengujian untuk memastikan model tidak overfitting.
#
#       **Menyimpan Model**:
#         1. Setelah model terlatih, simpan model dalam format yang dapat digunakan kembali (misalnya menggunakan pickle atau joblib dalam Python).
#
#     - Membangun API untuk Menggunakan Model
#
#       **Memilih Framework API**:
#         1. Pilih framework untuk membangun API seperti Flask, FastAPI, atau Django di Python.
#         2. Framework ini akan membantu Anda dalam membuat endpoint yang dapat diakses melalui HTTP requests.
#
#       **Menyiapkan Lingkungan**:
#         1. Pastikan Anda memiliki semua dependensi yang diperlukan (misalnya scikit-learn, TensorFlow, Flask).
#         2. Atur lingkungan virtual untuk mengelola dependensi.
#
#       **Mengimplementasikan API**:
#         1. Buat endpoint untuk menerima input data, memproses input tersebut, dan mengembalikan prediksi dari model machine learning.
#
#     - Mengamankan dan Mengoptimalkan API
#
#        **Autentikasi dan Otorisasi**:
#         1. Tambahkan lapisan keamanan untuk memastikan hanya pengguna yang berwenang yang dapat mengakses API. Contoh: menggunakan token API, OAuth, atau JWT (JSON Web Tokens).
#
#       **Penggunaan Rate Limiting**:
#         1. Batasi jumlah permintaan yang dapat dibuat oleh pengguna dalam jangka waktu tertentu untuk mencegah penyalahgunaan.
#
#       **Logging dan Monitoring**:
#         1. Implementasikan logging untuk melacak penggunaan API dan mendeteksi masalah.
#         2. Gunakan alat monitoring untuk memantau kinerja API dan mendapatkan wawasan tentang penggunaan.
#
#       **Optimasi Kinerja**:
#         1. Optimalkan kinerja API dengan caching hasil prediksi yang sering diminta.
#         2. Skala API menggunakan load balancer dan deploy pada infrastruktur yang mendukung skala besar seperti menggunakan Kubernetes.
#
#     -  Menguji dan Mendeploy API
#
#        **Pengujian**:
#         1. Lakukan pengujian unit dan integrasi untuk memastikan API berfungsi dengan benar.
#         2. Simulasikan permintaan dari klien untuk memastikan API merespon dengan benar dan cepat.
#
#        **Deployment**:
#         1. Deploy API ke lingkungan produksi menggunakan platform seperti AWS, Google Cloud, atau Azure.
#         2. Pastikan API dapat diakses secara publik atau sesuai dengan kebutuhan akses yang telah ditentukan.
#
#        **Dokumentasi**:
#         1. Buat dokumentasi yang jelas untuk API Anda, termasuk cara menggunakan endpoint, format input/output, dan contoh permintaan.
#
# 2. Jelaskan apa yang dimaksud dengan unsupervised learning!
#
#      Unsupervised learning adalah salah satu metode dalam machine learning di mana algoritma digunakan untuk menemukan pola atau struktur dalam data yang tidak memiliki label atau output yang telah ditentukan sebelumnya. Tidak seperti supervised learning yang menggunakan data berlabel untuk melatih model, unsupervised learning bekerja dengan data yang hanya memiliki input tanpa output yang terkait. Unsupervised learning berfokus pada menemukan pola tersembunyi atau struktur yang mendasari data. Algoritma mencoba mengidentifikasi hubungan antara data tanpa bimbingan dari output yang diketahui. Tujuannya adalah untuk menggali informasi yang bermanfaat dari data yang tidak terstruktur atau setengah terstruktur.
#
#     Ada beberapa jenis utama dari unsupervised learning di antaranya:
#
#      1. **Clustering**: Metode di mana data dikelompokkan ke dalam beberapa grup (cluster) berdasarkan kesamaan antar data. Data dalam satu cluster lebih mirip satu sama lain daripada data di cluster lain.
#      2. **Dimensionality Reduction**: Teknik untuk mengurangi jumlah fitur dalam data sambil mempertahankan informasi penting sebanyak mungkin. Ini membantu dalam visualisasi data dan mengurangi kompleksitas model.
#
# 3. Sebutkan beberapa tools yang di gunakan untuk mengolah machine learning
#
#     **Bahasa Pemrograman**
#     - Python
#     - R
#     - Java
#
#     **Libraries dan Frameworks**
#
#      Python Libraries:
#      - Scikit-Learn
#      - TensorFlow
#      - Keras
#      - PyTorch
#      - Pandas
#      - NumPy
#
#      R Libraries:
#      - Caret
#      - randomForest
#      - e1071
#      - nnet
#
#     **Tools dan Platforms**
#
#      Integrated Development Environments (IDEs):
#      - Jupyter Notebook
#      - PyCharm
#      - Rstudio
#
#      Cloud Platforms:
#      - Google Colab
#      - Amazon SageMaker
#      - Microsoft Azure Machine Learning
#
#     **Libraries untuk Visualisasi Data**
#      - Seaborn
#      - Plotly
#      - ggplot2 (R)
#
#     **Libraries untuk NLP**
#      - NLTK
#      - spaCy
#      - Transformers (Hugging Face)
#
#
# SOAL STUDI KASUS
#
# Soal untuk NIM Ganjil
# Dengan menggunakan Jupyter Notebook lakukan pengolahan text dari url berikut ini
# https://shared.djambred.my.id/uas-nim-ganjil.txt
# olah text tersebut sehingga dapat mengeluarkan hasil wordcloud, barplot frekuensi
# kata yang sering digunakan, plot terkait sentiment feel text tersebut.

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

text = """
[Long long time ago, in England in Sherwood Forest lived Robin Hood. 
When he was a boy , he had been cheated by a few noblemen. 
Since then he had decided that he would rob the rich and give what he got to the poor.
The Sheriff of Nottingham had made an advertisement that he would give many rewards for the capture of Robin Hood, nobody had ever caught him. 
It was because Robin Hood had a number of friends who served him. They acted as informers. 
When the Sheriff had any plan to catch him, they would warn Robin Hood.
Many rich people were scared of going through Sherwood Forest because they knew that Robin Hood would attack them. 
The Sheriff couldnâ€™t stand it anymore. 
Then he went to ask for the kingâ€™s help. 
However, the king refused to send any of his men to help in the capture of Robbin Hood.
One day The Sheriff and the noblemen held a competition to choose the best shooter in Nottingham. 
It was for capturing Robin Hood. 
Robin Hood was an excellent shooter. 
Therefore, Robin Hood would participate in the competition to prove that he was the best. 
He had been warned by his servant, but Robin wasnâ€™t willing to listen.
The competition began. 
William, The Sheriff man, and the man in green were trying for the first prize. 
it was time for the last arrow to be shot. 
The winner of this round would be declared the best shooter in Nottingham. 
William could shot very close to the center. 
Then the man in greenâ€™s turn made the crowd cheer hysterically. 
His arrow went through Williamâ€™s arrows and the center of the target. 
Then he shot two more arrows towards the chair on which the Sheriff sat. 
No doubt that the man in green was Robin Hood. 
immediately Robin Hood pulled of his black wig and then jumped over a wall onto his waiting horse and was gone. 
The Sheriff shouted to his men to catch him, but it was to late. 
Robin Hood escaped successfully]
"""

wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)

plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Word Cloud of Robin Hood Story')
plt.show()

# %%
from collections import Counter
import matplotlib.pyplot as plt
import seaborn as sns

text = """
Long long time ago, in England in Sherwood Forest lived Robin Hood. When he was a boy, he had been cheated by a few noblemen.
Since then he had decided that he would rob the rich and give what he got to the poor. The Sheriff of Nottingham had made an
advertisement that he would give many rewards for the capture of Robin Hood, nobody had ever caught him. It was because Robin
Hood had a number of friends who served him. They acted as informers. When the Sheriff had any plan to catch him, they would
warn Robin Hood. Many rich people were scared of going through Sherwood Forest because they knew that Robin Hood would attack
them. The Sheriff couldn’t stand it anymore. Then he went to ask for the king’s help. However, the king refused to send any
of his men to help in the capture of Robin Hood. One day The Sheriff and the noblemen held a competition to choose the best
shooter in Nottingham. It was for capturing Robin Hood. Robin Hood was an excellent shooter. Therefore, Robin Hood would
participate in the competition to prove that he was the best. He had been warned by his servant, but Robin wasn’t willing to
listen. The competition began. William, The Sheriff man, and the man in green were trying for the first prize. It was time for
the last arrow to be shot. The winner of this round would be declared the best shooter in Nottingham. William could shot very
close to the center. Then the man in green’s turn made the crowd cheer hysterically. His arrow went through William’s arrows
and the center of the target. Then he shot two more arrows towards the chair on which the Sheriff sat. No doubt that the man in
green was Robin Hood. Immediately Robin Hood pulled of his black wig and then jumped over a wall onto his waiting horse and was
gone. The Sheriff shouted to his men to catch him, but it was too late. Robin Hood escaped successfully.
"""

words = text.lower().split()
word_freq = Counter(words)

common_words = word_freq.most_common(10)
words, frequencies = zip(*common_words)

plt.figure(figsize=(10, 5))
sns.barplot(x=list(words), y=list(frequencies))
plt.title('Top 10 Most Frequent Words')
plt.xlabel('Words')
plt.ylabel('Frequencies')
plt.show()

# %%
import matplotlib.pyplot as plt
import nltk
from nltk.sentiment import SentimentIntensityAnalyzer

# Teks input
text = """
Long long time ago, in England in Sherwood Forest lived Robin Hood. When he was a boy, he had been cheated by a few noblemen. 
Since then he had decided that he would rob the rich and give what he got to the poor. 
The Sheriff of Nottingham had made an advertisement that he would give many rewards for the capture of Robin Hood, nobody had ever caught him. 
It was because Robin Hood had a number of friends who served him. They acted as informers. 
When the Sheriff had any plan to catch him, they would warn Robin Hood. 
Many rich people were scared of going through Sherwood Forest because they knew that Robin Hood would attack them. 
The Sheriff couldn’t stand it anymore. 
Then he went to ask for the king’s help. However, the king refused to send any of his men to help in the capture of Robin Hood. 
One day The Sheriff and the noblemen held a competition to choose the best shooter in Nottingham. It was for capturing Robin Hood. 
Robin Hood was an excellent shooter. Therefore, Robin Hood would participate in the competition to prove that he was the best. 
He had been warned by his servant, but Robin wasn’t willing to listen. 
The competition began. William, The Sheriff man, and the man in green were trying for the first prize. 
It was time for the last arrow to be shot. The winner of this round would be declared the best shooter in Nottingham. 
William could shot very close to the center. Then the man in green’s turn made the crowd cheer hysterically. 
His arrow went through William’s arrows and the center of the target. 
Then he shot two more arrows towards the chair on which the Sheriff sat. No doubt that the man in green was Robin Hood. 
immediately Robin Hood pulled off his black wig and then jumped over a wall onto his waiting horse and was gone. 
The Sheriff shouted to his men to catch him, but it was too late. Robin Hood escaped successfully.
"""

nltk.download('vader_lexicon')

# Analisis Sentimen menggunakan SentimentIntensityAnalyzer
sia = SentimentIntensityAnalyzer()
sentiment_scores = sia.polarity_scores(text)
print("Sentiment Scores:", sentiment_scores)

# Diagram Lingkaran untuk Sentimen
labels = ['Positive', 'Negative', 'Neutral', 'Compound']
sizes = [sentiment_scores['pos'], sentiment_scores['neg'], sentiment_scores['neu'], sentiment_scores['compound']]
colors = ['#00ff00', '#ff0000', '#00bfff', '#800080']  # Warna kontras untuk setiap kategori

fig1, ax1 = plt.subplots()
ax1.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=90)
ax1.axis('equal')
plt.title('Sentiment Analysis')
plt.show()
# Out:
# Sentiment Scores: {'neg': 0.055, 'neu': 0.826, 'pos': 0.119, 'compound': 0.9806}
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\hi\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
